# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\casey\\Downloads\\Python-Data-Science-and-Machine-Learning-Bootcamp-master\\Python-for-Data-Visualization\\Pandas Built-in Data Viz'

# %%
os.chdir('C:\\Users\\casey\\Downloads\\Python-Data-Science-and-Machine-Learning-Bootcamp-master\\Python-for-Data-Visualization\\Pandas Built-in Data Viz')

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# built in histogram function

df1['A'].hist()

# %%
df1['A'].hist(bins = 30) # can pass in arguments

# %%
import seaborn as sns

# %%
# now that seaborn is imported, the plots will look like seaborn plots
df1['A'].hist(bins = 30) # not working

# %%
df1['A'].plot(kind = 'hist') # another way to do it

# %%
df1['A'].plot.hist() # another way to do it

# %%
# using df2 now

df2.plot.area(alpha = 0.5)

# %%
df2.plot.bar()

# %%
df1['A'].plot.hist(bins = 50)

# %%
# for line plots, x and y can be specified in the function (using index as x so don't need to specify here)

df1.plot.line(y = 'B', figsize = (12, 3), lw = 0.8) # all matplotlib arguments are still applicable too

# %%
# scatter plot

df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm')

# %%
# column C by size

df1.plot.scatter(x = 'A', y = 'B', s = df1['C']*100)
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# boxplot

df2.plot.box()

# %%
# hexbins

df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])

df.plot.hexbin(x = 'a', y = 'b', gridsize = 20, cmap = 'cool')

# %%
# Kernel density estimation (KDE)

df2['a'].plot.kde()

# %%
df2['a'].plot.density() # same thing

# %%
df2.plot.density() # all columns included
